# %%
import tushare as ts
import pandas as pd

# %%
ts.set_token('53cd3b985c649c978160c6ec04bce24f4fbd2ebcb4673e8f2fba9a43')

pro = ts.pro_api()

# %%
data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
data.head()
# Out:
#      ts_code  symbol  name area industry list_date
# 0  000001.SZ  000001  平安银行   深圳       银行  19910403
# 1  000002.SZ  000002   万科A   深圳     全国地产  19910129
# 2  000004.SZ  000004  国农科技   深圳     生物制药  19910114
# 3  000005.SZ  000005  世纪星源   深圳     环境保护  19901210
# 4  000006.SZ  000006  深振业A   深圳     区域地产  19920427

# %%
code_list = data['ts_code'].values

# %%
code_list[:10]
# Out:
# array(['000001.SZ', '000002.SZ', '000004.SZ', '000005.SZ', '000006.SZ',
#        '000007.SZ', '000008.SZ', '000009.SZ', '000010.SZ', '000011.SZ'],
#       dtype=object)

# %%
start_date = '20160817'
end_date = '20190817'
for code in code_list:
    price = ts.pro_bar(ts_code=code, asset="E", adj="qfq", start_date=start_date, end_date=end_date)
    price = price.drop(['ts_code'], axis=1)
    price['trade_date'] = pd.to_datetime(price['trade_date'])
    price = price.set_index('trade_date')
    price = price[::-1]
    price.to_csv('./data/stock_price/{}.csv'.format(code))
# Out:
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EFCA81E080>, 'Connection to api.waditu.com timed out. (connect timeout=15)'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EFCA07D668>, 'Connection to api.waditu.com timed out. (connect timeout=15)'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EFCA0A34E0>, 'Connection to api.waditu.com timed out. (connect timeout=15)'))

# %%
start_date = '20160817'
end_date = '20190817'
for code in code_list[:1]:
    df = pro.top10_holders(ts_code=code, start_date=start_date, end_date=end_date)
df
# Out:
#       ts_code  ann_date  end_date                          holder_name  \
# 0   000001.SZ  20190808  20190630                         中国证券金融股份有限公司
# 1   000001.SZ  20190808  20190630   中信信托有限责任公司-中信信托锐进43期高毅晓峰投资集合资金信托计划
# 2   000001.SZ  20190808  20190630                         深圳中电投资股份有限公司
# 3   000001.SZ  20190808  20190630             中国平安人寿保险股份有限公司-传统-普通保险产品
# 4   000001.SZ  20190808  20190630                          全国社保基金一零四组合
# 5   000001.SZ  20190808  20190630                         河南鸿宝企业管理有限公司
# 6   000001.SZ  20190808  20190630                      香港中央结算有限公司(陆股通)
# 7   000001.SZ  20190808  20190630                       中央汇金资产管理有限责任公司
# 8   000001.SZ  20190808  20190630                  中国平安人寿保险股份有限公司-自有资金
# 9   000001.SZ  20190808  20190630           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 10  000001.SZ  20190424  20190331           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 11  000001.SZ  20190424  20190331                  中国平安人寿保险股份有限公司-自有资金
# 12  000001.SZ  20190424  20190331                      香港中央结算有限公司(陆股通)
# 13  000001.SZ  20190424  20190331                         中国证券金融股份有限公司
# 14  000001.SZ  20190424  20190331             中国平安人寿保险股份有限公司-传统-普通保险产品
# 15  000001.SZ  20190424  20190331                       中央汇金资产管理有限责任公司
# 16  000001.SZ  20190424  20190331                         深圳中电投资股份有限公司
# 17  000001.SZ  20190424  20190331                           河南鸿宝集团有限公司
# 18  000001.SZ  20190424  20190331   中信信托有限责任公司-中信信托锐进43期高毅晓峰投资集合资金信托计划
# 19  000001.SZ  20190424  20190331        上海高毅资产管理合伙企业(有限合伙)-高毅晓峰2号致信基金
# 20  000001.SZ  20190307  20181231           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 21  000001.SZ  20190307  20181231                  中国平安人寿保险股份有限公司-自有资金
# 22  000001.SZ  20190307  20181231                      香港中央结算有限公司(陆股通)
# 23  000001.SZ  20190307  20181231                         中国证券金融股份有限公司
# 24  000001.SZ  20190307  20181231             中国平安人寿保险股份有限公司-传统-普通保险产品
# 25  000001.SZ  20190307  20181231                       中央汇金资产管理有限责任公司
# 26  000001.SZ  20190307  20181231                         深圳中电投资股份有限公司
# 27  000001.SZ  20190307  20181231                           河南鸿宝集团有限公司
# 28  000001.SZ  20190307  20181231    新华人寿保险股份有限公司-分红-个人分红-0 18L-FH002深
# 29  000001.SZ  20190307  20181231                   交通银行-易方达50指数证券投资基金
# ..        ...       ...       ...                                  ...
# 70  000001.SZ  20180315  20171231                      香港中央结算有限公司(陆股通)
# 71  000001.SZ  20171021  20170930           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 72  000001.SZ  20171021  20170930                  中国平安人寿保险股份有限公司-自有资金
# 73  000001.SZ  20171021  20170930                         中国证券金融股份有限公司
# 74  000001.SZ  20171021  20170930             中国平安人寿保险股份有限公司-传统-普通保险产品
# 75  000001.SZ  20171021  20170930                       中央汇金资产管理有限责任公司
# 76  000001.SZ  20171021  20170930                         深圳中电投资股份有限公司
# 77  000001.SZ  20171021  20170930                        深圳市正顺资本控股有限公司
# 78  000001.SZ  20171021  20170930               南方基金-农业银行-南方中证金融资产管理计划
# 79  000001.SZ  20171021  20170930               中欧基金-农业银行-中欧中证金融资产管理计划
# 80  000001.SZ  20171021  20170930                      香港中央结算有限公司(陆股通)
# 81  000001.SZ  20170422  20170331           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 82  000001.SZ  20170422  20170331                  中国平安人寿保险股份有限公司-自有资金
# 83  000001.SZ  20170422  20170331                         中国证券金融股份有限公司
# 84  000001.SZ  20170422  20170331             中国平安人寿保险股份有限公司-传统-普通保险产品
# 85  000001.SZ  20170422  20170331                       中央汇金资产管理有限责任公司
# 86  000001.SZ  20170422  20170331                         深圳中电投资股份有限公司
# 87  000001.SZ  20170422  20170331                        深圳市正顺资本控股有限公司
# 88  000001.SZ  20170422  20170331  东海瑞京资管-浦发银行-东海瑞京-浦发银行-瑞龙18号专项资产管理计划
# 89  000001.SZ  20170422  20170331           工银瑞信基金-农业银行-工银瑞信中证金融资产管理计划
# 90  000001.SZ  20170422  20170331               南方基金-农业银行-南方中证金融资产管理计划
# 91  000001.SZ  20170317  20161231           中国平安保险(集团)股份有限公司-集团本级-自有资金
# 92  000001.SZ  20170317  20161231                  中国平安人寿保险股份有限公司-自有资金
# 93  000001.SZ  20170317  20161231                         中国证券金融股份有限公司
# 94  000001.SZ  20170317  20161231             中国平安人寿保险股份有限公司-传统-普通保险产品
# 95  000001.SZ  20170317  20161231                       中央汇金资产管理有限责任公司
# 96  000001.SZ  20170317  20161231                         深圳中电投资股份有限公司
# 97  000001.SZ  20170317  20161231                        深圳市正顺资本控股有限公司
# 98  000001.SZ  20170317  20161231               天治基金-民生银行-天治平安1号资产管理计划
# 99  000001.SZ  20170317  20161231  东海瑞京资管-浦发银行-东海瑞京-浦发银行-瑞龙18号专项资产管理计划
#
#      hold_amount  hold_ratio
# 0   4.292327e+08        2.50
# 1   5.641375e+07        0.33
# 2   1.424028e+08        0.83
# 3   3.897360e+08        2.27
# 4   5.516938e+07        0.32
# 5   9.771491e+07        0.57
# 6   7.112212e+08        4.14
# 7   2.162130e+08        1.26
# 8   1.049463e+09        6.11
# 9   8.510493e+09       49.56
# 10  8.510493e+09       49.56
# 11  1.049463e+09        6.11
# 12  7.166605e+08        4.17
# 13  4.292327e+08        2.50
# 14  3.897360e+08        2.27
# 15  2.162130e+08        1.26
# 16  1.424028e+08        0.83
# 17  1.004533e+08        0.59
# 18  6.634607e+07        0.39
# 19  4.922192e+07        0.29
# 20  8.510493e+09       49.56
# 21  1.049463e+09        6.11
# 22  4.307515e+08        2.51
# 23  4.292327e+08        2.50
# 24  3.897360e+08        2.27
# 25  2.162130e+08        1.26
# 26  1.424028e+08        0.83
# 27  9.944111e+07        0.58
# 28  4.960350e+07        0.29
# 29  4.414380e+07        0.26
# ..           ...         ...
# 70  3.647691e+08        2.12
# 71  8.510493e+09       49.56
# 72  1.049463e+09        6.11
# 73  4.621721e+08        2.69
# 74  3.897360e+08        2.27
# 75  2.162130e+08        1.26
# 76  1.860519e+08        1.08
# 77  1.066864e+08        0.62
# 78  6.373116e+07        0.37
# 79  6.373116e+07        0.37
# 80  1.555839e+08        0.91
# 81  8.510493e+09       49.56
# 82  1.049463e+09        6.11
# 83  4.793708e+08        2.79
# 84  3.897360e+08        2.27
# 85  2.162130e+08        1.26
# 86  1.912519e+08        1.11
# 87  1.066864e+08        0.62
# 88  8.931474e+07        0.52
# 89  6.373116e+07        0.37
# 90  6.373116e+07        0.37
# 91  8.510493e+09       49.56
# 92  1.049463e+09        6.11
# 93  4.793708e+08        2.79
# 94  3.897360e+08        2.27
# 95  2.162130e+08        1.26
# 96  1.912519e+08        1.11
# 97  1.066864e+08        0.62
# 98  9.464376e+07        0.55
# 99  8.931474e+07        0.52
#
# [100 rows x 6 columns]
